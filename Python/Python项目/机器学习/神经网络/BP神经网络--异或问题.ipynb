# %%
for i in range(20000):
    update()#更新权值
    if i%500==0:
        L1 = sigmoid(np.dot(X,V))#隐藏层输出(4,4)
        L2 = sigmoid(np.dot(L1,W))#输出层输出(4,1)
        print('Error:',np.mean(np.abs(Y.T-L2)))
        
L1 = sigmoid(np.dot(X,V))#隐藏层输出(4,4)
L2 = sigmoid(np.dot(L1,W))#输出层输出(4,1)
print(L2)

def judge(x):
    if x>=0.5:
        return 1
    else:
        return 0

for i in map(judge,L2):
    print(i)
# Out:
# Error: 0.5001183198127299
# Error: 0.4989478677853284
# Error: 0.49656025552063965
# Error: 0.48757557418244235
# Error: 0.4575744849687189
# Error: 0.39811943626386614
# Error: 0.3092902911279684
# Error: 0.21170745731963542
# Error: 0.15144924126616743
# Error: 0.11800950582684311
# Error: 0.0977296737999466
# Error: 0.08424244936759885
# Error: 0.07461964879875069
# Error: 0.06738694171797942
# Error: 0.06173290125723552
# Error: 0.05717670322231022
# Error: 0.05341588071234772
# Error: 0.05025069709559749
# Error: 0.04754388232630195
# Error: 0.04519790645011616
# Error: 0.04314150272697238
# Error: 0.04132133305166252
# Error: 0.03969664441084146
# Error: 0.03823573440565815
# Error: 0.03691354882229275
# Error: 0.0357100090661284
# Error: 0.03460882273908608
# Error: 0.03359662163273519
# Error: 0.032662326311033794
# Error: 0.03179667049495152
# Error: 0.030991840087820945
# Error: 0.03024119572850959
# Error: 0.02953905707040503
# Error: 0.028880533269544692
# Error: 0.028261388480056337
# Error: 0.027677934163264743
# Error: 0.027126942144120862
# Error: 0.02660557387292225
# Error: 0.0261113224559572
# Error: 0.025641964829854827
# [[0.01593862]
#  [0.97745636]
#  [0.97227975]
#  [0.03458307]]
# 0
# 1
# 1
# 0
